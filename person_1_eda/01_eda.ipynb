# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import sys
print(sys.executable)

# %%
pd set_option("display.max_columns", None)
pd.set_option("display.max_row", 100)

# %%
df = pd.read_csv("../data/raw/01_student_pass_fail.csv")
